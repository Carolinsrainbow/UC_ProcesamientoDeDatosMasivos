# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolinsrainbow/UC_ProcesamientoDeDatosMasivos/blob/main/Tarea2_webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instrucciones
#
# ¡Bienvenido(a)!
#
# Te invitamos a realizar una actividad para que pongas en práctica lo aprendido en el curso.
#
# Características de la evaluación
#
# - Tipo de actividad: grupal
# - Tipo de evaluación: Sumativa (con calificación)
# - Ponderación: 10% (Equivale al 10% de la nota final del curso)
# - Puntaje: 24 puntos

# %% [markdown]
# .
# Pregunta 1
#      Preguntas
#
# 1.  Utiliza Python Extraer información, desde la página web:
# http://books.toscrape.com/

# %%
import requests
from bs4 import BeautifulSoup

url = "http://books.toscrape.com/"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")

#print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# 2.  Examina el código fuente de la página web:
#
# El método para hacerlo depende del navegador que estés utilizando. Considera que esta página contiene un catálogo de libros, el catálogo cuenta con un total de 1000 libros, pero se muestran 20 a la vez, por lo que para revisarlos todos debes hacer repetidamente click en el botón “next”.
#
# 3.  Escribe un programa en python que imprima en la consola:
#
# Los links de todos los libros que tengan una calificación de 5 estrellas en la página 1 de http://books.toscrape.com/

# %%
books = soup.find_all('article', class_='product_pod')

five_star_books = []
for book in books:
    if "star-rating Five" in str(book):
        book_link = book.find("h3").find("a")["href"]
        absolute_link = requests.compat.urljoin(url, book_link)
        five_star_books.append(absolute_link)

print("Links de los libros con calificación de 5 estrellas para la página 1:")
for link in five_star_books:
    print(link)
# Out:
# Links de los libros con calificación de 5 estrellas para la página 1:
# http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# http://books.toscrape.com/catalogue/set-me-free_988/index.html
# http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html

# %% [markdown]
# 4.  Extiende tu programa para extraer e imprimir:
#
# Todos los libros del catálogo completo (las 50 páginas) cuyo rating sea igual a 5 estrellas.

# %%
def completeSearch(url):
    results = []

    while url:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")

        books = soup.find_all('article', class_='product_pod')
        for book in books:
            if "star-rating Five" in str(book):
                book_link = book.find("h3").find("a")["href"]
                absolute_link = requests.compat.urljoin(url, book_link)
                results.append(absolute_link)

        next_button = soup.find("li", class_="next")
        if next_button:
            url = requests.compat.urljoin(url, next_button.find("a")["href"])
        else:
            url = None

    return results

base_url = "http://books.toscrape.com/"
complete5star = completeSearch(base_url)

print("Links de todos los libros con calificación de 5 estrellas:")
for link in complete5star:
    print(link)
# Out:
# Links de todos los libros con calificación de 5 estrellas:
# http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# http://books.toscrape.com/catalogue/set-me-free_988/index.html
# http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html
# http://books.toscrape.com/catalogue/chase-me-paris-nights-2_977/index.html
# http://books.toscrape.com/catalogue/black-dust_976/index.html
# http://books.toscrape.com/catalogue/worlds-elsewhere-journeys-around-shakespeares-globe_972/index.html
# http://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html
# http://books.toscrape.com/catalogue/the-elephant-tree_968/index.html
# http://books.toscrape.com/catalogue/sophies-world_966/index.html
# http://books.toscrape.com/catalogue/private-paris-private-10_958/index.html
# ...
